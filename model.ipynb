# %%
#depenencies

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import RFE, SelectKBest, chi2
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegressionCV

# %%
#import data
training_data = pd.read_csv('data/training_data.csv')

training_data
# Out:
#            dates results locations  game_nums opponent  date_diff  rest  \
# 0     2017-10-18     Win      Away          1      BOS         10     9
# 1     2017-10-20    Loss      Home          2      CLE          2     1
# 2     2017-10-21     Win      Home          3      POR          1     0
# 3     2017-10-23     Win      Home          4      CHO          2     1
# 4     2017-10-26    Loss      Home          5      BOS          3     2
# ...          ...     ...       ...        ...      ...        ...   ...
# 7375  2016-04-05     Win      Away         78      MIL          2     1
# 7376  2016-04-06    Loss      Away         79      IND          1     0
# 7377  2016-04-09    Loss      Away         80      CHI          3     2
# 7378  2016-04-11     Win      Home         81      ATL          2     1
# 7379  2016-04-13    Loss      Home         82      DET          2     1
#
#       opp_date_diff  opp_rest  rest_diff abbrv
# 0              10.0       9.0        0.0   MIL
# 1               3.0       2.0       -1.0   MIL
# 2               1.0       0.0        0.0   MIL
# 3               2.0       1.0        0.0   MIL
# 4               2.0       1.0        1.0   MIL
# ...             ...       ...        ...   ...
# 7375            2.0       1.0        0.0   CLE
# 7376            2.0       1.0       -1.0   CLE
# 7377            2.0       1.0        1.0   CLE
# 7378            2.0       1.0        0.0   CLE
# 7379            1.0       0.0        1.0   CLE
#
# [7380 rows x 11 columns]

# %%
#feature engineering

# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column

training_data['opponent_lab'] = labelencoder.fit_transform(training_data['opponent'])
training_data['locations_lab'] = labelencoder.fit_transform(training_data['locations'])
training_data['abbrv_lab'] = labelencoder.fit_transform(training_data['abbrv'])
training_data['results_lab'] = labelencoder.fit_transform(training_data['results'])

training_data
# Out:
#            dates results locations  game_nums opponent  date_diff  rest  \
# 0     2017-10-18     Win      Away          1      BOS         10     9
# 1     2017-10-20    Loss      Home          2      CLE          2     1
# 2     2017-10-21     Win      Home          3      POR          1     0
# 3     2017-10-23     Win      Home          4      CHO          2     1
# 4     2017-10-26    Loss      Home          5      BOS          3     2
# ...          ...     ...       ...        ...      ...        ...   ...
# 7375  2016-04-05     Win      Away         78      MIL          2     1
# 7376  2016-04-06    Loss      Away         79      IND          1     0
# 7377  2016-04-09    Loss      Away         80      CHI          3     2
# 7378  2016-04-11     Win      Home         81      ATL          2     1
# 7379  2016-04-13    Loss      Home         82      DET          2     1
#
#       opp_date_diff  opp_rest  rest_diff abbrv  opponent_lab  locations_lab  \
# 0              10.0       9.0        0.0   MIL             1              0
# 1               3.0       2.0       -1.0   MIL             5              1
# 2               1.0       0.0        0.0   MIL            24              1
# 3               2.0       1.0        0.0   MIL             4              1
# 4               2.0       1.0        1.0   MIL             1              1
# ...             ...       ...        ...   ...           ...            ...
# 7375            2.0       1.0        0.0   CLE            16              0
# 7376            2.0       1.0       -1.0   CLE            11              0
# 7377            2.0       1.0        1.0   CLE             3              0
# 7378            2.0       1.0        0.0   CLE             0              1
# 7379            1.0       0.0        1.0   CLE             8              1
#
#       abbrv_lab  results_lab
# 0            16            1
# 1            16            0
# 2            16            1
# 3            16            1
# 4            16            0
# ...         ...          ...
# 7375          5            1
# 7376          5            0
# 7377          5            0
# 7378          5            1
# 7379          5            0
#
# [7380 rows x 15 columns]

# %%
training_data.columns
# Out:
# Index(['dates', 'results', 'locations', 'game_nums', 'opponent', 'date_diff',
#        'rest', 'opp_date_diff', 'opp_rest', 'rest_diff', 'abbrv',
#        'opponent_lab', 'locations_lab', 'abbrv_lab', 'results_lab'],
#       dtype='object')

# %%
#separate x and y
data = training_data[['game_nums', 'date_diff',
       'rest', 'opp_date_diff', 'opp_rest', 'rest_diff',
       'opponent_lab', 'locations_lab', 'abbrv_lab', 'results_lab']]

X = data.iloc[:,0:8]
y = data.iloc[:,9].to_list()

# %%
#svm estimator and recursive feature selection

svm_estimator = svm.SVC(kernel='linear') 


rfe = RFE(estimator= svm_estimator, 
          verbose=1, 
          n_features_to_select= 4
         )

rfe.fit(X, y)
# Out:
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# RFE(estimator=SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                   coef0=0.0, decision_function_shape='ovr', degree=3,
#                   gamma='scale', kernel='linear', max_iter=-1,
#                   probability=False, random_state=None, shrinking=True,
#                   tol=0.001, verbose=False),
#     n_features_to_select=4, step=1, verbose=1)

# %%
#top 4 features
cols = rfe.get_support(indices=True)
X_new = X.iloc[:,cols]
X_new.columns
# Out:
# Index(['rest', 'opp_rest', 'rest_diff', 'locations_lab'], dtype='object')

# %%
#Standardize the input features
scaler = MinMaxScaler(feature_range=(.1,.9) 

X_stand = scaler.fit_transform(X)

# %%
#standardized rfe

svm_estimator = svm.SVC(kernel='linear') 

#TODO: Recursive Feature Elimination
rfe = RFE(estimator= svm_estimator, 
          verbose=1, 
          n_features_to_select= 4
         )

rfe.fit(X_stand, y) #Note: this may take a few minutes to complete
# Out:
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# RFE(estimator=SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                   coef0=0.0, decision_function_shape='ovr', degree=3,
#                   gamma='scale', kernel='linear', max_iter=-1,
#                   probability=False, random_state=None, shrinking=True,
#                   tol=0.001, verbose=False),
#     n_features_to_select=4, step=1, verbose=1)

# %%
#TODO: display the names of the selected features below
cols = rfe.get_support(indices=True)
X_new = X.iloc[:,cols]
X_new.columns
# Out:
# Index(['game_nums', 'rest', 'opponent_lab', 'locations_lab'], dtype='object')

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear', C=1, random_state=42)
scores = cross_val_score(clf, X, y, cv=5)
scores
# Out:
# array([0.56097561, 0.59823848, 0.58197832, 0.58604336, 0.59146341])

# %%
#random forest ensemble
#separate x and y
data = training_data[['game_nums', 'date_diff',
       'rest', 'opp_date_diff', 'opp_rest', 'rest_diff',
       'opponent_lab', 'locations_lab', 'abbrv_lab', 'results_lab']]

X = data.iloc[:,0:8].to_numpy()
y = data.iloc[:,9].to_list()

# %%
#splitting into training and test sets
seed = 42

#Standardize the input features
scaler = MinMaxScaler(feature_range=(.0,.99) #TODO: provide the min and max values for the features
                     )

X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = .35, 
                                                    random_state = seed,
                                                    stratify = y
                                                   )

# %%
#Create the RandomForestClassifier

rf_classifier = RandomForestClassifier(criterion= 'gini', 
                                    max_depth= 15,     
                                    max_features= "auto",  
                                    min_samples_split= 10, 
                                    n_estimators= 100, 
                                    random_state= 42 
                                    )

#Train classifer using the `fit` method
rf_classifier.fit(X_train,y_train)

#Make predictions with the test set
y_pred = rf_classifier.predict(X_test)

#evaluate the accuracy
round(accuracy_score(y_test,y_pred),4)
# Out:
# 0.585

# %%
#log res

clf = LogisticRegressionCV(cv=5, random_state=42).fit(X_train, y_train)
y_pred = clf.predict(X_test)


round(accuracy_score(y_test,y_pred),4)
# Out:
# 0.583

# %%
#testing more scores
from sklearn.model_selection import cross_val_score
svc = svm.SVC(kernel='linear', C=1, random_state=42)
scores = cross_val_score(svc, X_train, y_train, cv=5)
scores
# Out:
# array([0.57291667, 0.584375  , 0.58498436, 0.58602711, 0.59228363])

# %%
# test on unseen data
test_data = pd.read_csv('data/test_data.csv')

# %%
#reloading training data so it is unprocessed
training_data = pd.read_csv('data/training_data.csv')

# %%
#process both sets 

# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column

training_data['opponent_lab'] = labelencoder.fit_transform(training_data['opponent'])
training_data['locations_lab'] = labelencoder.fit_transform(training_data['locations'])
training_data['abbrv_lab'] = labelencoder.fit_transform(training_data['abbrv'])
training_data['results_lab'] = labelencoder.fit_transform(training_data['results'])

training_data
# Out:
#            dates results locations  game_nums opponent  date_diff  rest  \
# 0     2017-10-18     Win      Away          1      BOS         10     9
# 1     2017-10-20    Loss      Home          2      CLE          2     1
# 2     2017-10-21     Win      Home          3      POR          1     0
# 3     2017-10-23     Win      Home          4      CHO          2     1
# 4     2017-10-26    Loss      Home          5      BOS          3     2
# ...          ...     ...       ...        ...      ...        ...   ...
# 7375  2016-04-05     Win      Away         78      MIL          2     1
# 7376  2016-04-06    Loss      Away         79      IND          1     0
# 7377  2016-04-09    Loss      Away         80      CHI          3     2
# 7378  2016-04-11     Win      Home         81      ATL          2     1
# 7379  2016-04-13    Loss      Home         82      DET          2     1
#
#       opp_date_diff  opp_rest  rest_diff abbrv  opponent_lab  locations_lab  \
# 0              10.0       9.0        0.0   MIL             1              0
# 1               3.0       2.0       -1.0   MIL             5              1
# 2               1.0       0.0        0.0   MIL            24              1
# 3               2.0       1.0        0.0   MIL             4              1
# 4               2.0       1.0        1.0   MIL             1              1
# ...             ...       ...        ...   ...           ...            ...
# 7375            2.0       1.0        0.0   CLE            16              0
# 7376            2.0       1.0       -1.0   CLE            11              0
# 7377            2.0       1.0        1.0   CLE             3              0
# 7378            2.0       1.0        0.0   CLE             0              1
# 7379            1.0       0.0        1.0   CLE             8              1
#
#       abbrv_lab  results_lab
# 0            16            1
# 1            16            0
# 2            16            1
# 3            16            1
# 4            16            0
# ...         ...          ...
# 7375          5            1
# 7376          5            0
# 7377          5            0
# 7378          5            1
# 7379          5            0
#
# [7380 rows x 15 columns]

# %%
# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column

test_data['opponent_lab'] = labelencoder.fit_transform(test_data['opponent'])
test_data['locations_lab'] = labelencoder.fit_transform(test_data['locations'])
test_data['abbrv_lab'] = labelencoder.fit_transform(test_data['abbrv'])
test_data['results_lab'] = labelencoder.fit_transform(test_data['results'])

test_data
# Out:
#            dates results locations  game_nums opponent  date_diff  rest  \
# 0     2018-10-17     Win      Away          1      CHO         10     9
# 1     2018-10-19     Win      Home          2      IND          2     1
# 2     2018-10-22     Win      Home          3      NYK          3     2
# 3     2018-10-24     Win      Home          4      PHI          2     1
# 4     2018-10-26     Win      Away          5      MIN          2     1
# ...          ...     ...       ...        ...      ...        ...   ...
# 2455  2019-04-01    Loss      Away         78      PHO          2     1
# 2456  2019-04-04    Loss      Away         79      SAC          3     2
# 2457  2019-04-05    Loss      Away         80      GSW          1     0
# 2458  2019-04-07    Loss      Home         81      SAS          2     1
# 2459  2019-04-09    Loss      Home         82      CHO          2     1
#
#       opp_date_diff  opp_rest  rest_diff abbrv  opponent_lab  locations_lab  \
# 0              10.0       9.0        0.0   MIL             4              0
# 1               2.0       1.0        0.0   MIL            11              1
# 2               1.0       0.0        2.0   MIL            19              1
# 3               3.0       2.0       -1.0   MIL            22              1
# 4               2.0       1.0        0.0   MIL            17              0
# ...             ...       ...        ...   ...           ...            ...
# 2455            2.0       1.0        0.0   CLE            23              0
# 2456            2.0       1.0        1.0   CLE            25              0
# 2457            2.0       1.0       -1.0   CLE             9              0
# 2458            2.0       1.0        0.0   CLE            26              1
# 2459            1.0       0.0        1.0   CLE             4              1
#
#       abbrv_lab  results_lab
# 0            16            1
# 1            16            1
# 2            16            1
# 3            16            1
# 4            16            1
# ...         ...          ...
# 2455          5            0
# 2456          5            0
# 2457          5            0
# 2458          5            0
# 2459          5            0
#
# [2460 rows x 15 columns]

# %%
#random forest ensemble

#separate x and y training
train = training_data[['game_nums', 'date_diff',
       'rest', 'opp_date_diff', 'opp_rest', 'rest_diff',
       'opponent_lab', 'locations_lab', 'abbrv_lab', 'results_lab']]

X_train = data.iloc[:,0:8].to_numpy()
y_train = data.iloc[:,9].to_list()

# %%
#separate x and y training
test = test_data[['game_nums', 'date_diff',
       'rest', 'opp_date_diff', 'opp_rest', 'rest_diff',
       'opponent_lab', 'locations_lab', 'abbrv_lab', 'results_lab']]

X_test = data.iloc[:,0:8].to_numpy()
y_test = data.iloc[:,9].to_list()

# %%
#scaling both X sets


#Standardize the input features
scaler = MinMaxScaler(feature_range=(.0,.99) 
                     )

X_train = scaler.fit_transform(X_train)

X_test = scaler.fit_transform(X_test)

# %%
#Create the RandomForestClassifier

rf_classifier = RandomForestClassifier(criterion= 'gini', 
                                    max_depth= 15,     
                                    max_features= "auto",  
                                    min_samples_split= 10, 
                                    n_estimators= 100, 
                                    random_state= 42 
                                    )

#Train classifer using the `fit` method
rf_classifier.fit(X_train,y_train)

#Make predictions with the test set
y_pred = rf_classifier.predict(X_test)

#evaluate the accuracy
round(accuracy_score(y_test,y_pred),4)
# Out:
# 0.7659

# %%
#log res

clf = LogisticRegressionCV(cv=5, random_state=42).fit(X_train, y_train)
y_pred = clf.predict(X_test)


round(accuracy_score(y_test,y_pred),4)
# Out:
# 0.5837

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test, y_pred)
r2 = rf_classifier.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.23414634146341465, R2: 0.7658536585365854
