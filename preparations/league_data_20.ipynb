# %%
#Dependencies
import pandas as pd
import numpy as np
from sportsreference.nba.schedule import Schedule
from datetime import date, datetime

# %%
#creating the rest day calc function

def rest_days_20(team):
    
    #creating the team schedule
    schedule = Schedule(team, 2020)
    
    dates = []
    results = []
    locations = []
    game_nums = []
    opponents = []

    
    
    for game in schedule:
    
        if game.playoffs == False and game.datetime < datetime(2020,7,15):
            dates.append(game.datetime)
            results.append(game.result)
            locations.append(game.location)
            game_nums.append(game.game)
            opponents.append(game.opponent_abbr)
            
    #creating team dictionary
    team_dict = {
        "dates": dates,
        "results": results,
        "locations": locations,
        "game_nums": game_nums,
        "opponent": opponents
    }
    
    #creating bucks data frame
    team_df = pd.DataFrame(team_dict)
    team_df
    
    #finding the number of games between each game
    team_df["date_diff"] = 0

    for i in range(1,len(team_df)):    
        team_df["date_diff"][i] = team_df["dates"][i] - team_df["dates"][(i-1)]
    
    #inserting value for the date diff in the first game
    #using 10 as a standard for the date difference of the first game (most impactful players don't play preseason anyway)
    team_df["date_diff"][0] = 10

    #converting to a time delta
    team_df["date_diff"][0] = pd.to_timedelta(team_df["date_diff"][0], unit = "D")
    
    #Converting the date difference series back into an integer for easier comparisons
    for day in range(0,len(team_df["date_diff"])):
        team_df["date_diff"][day] = team_df["date_diff"][day] / np.timedelta64(1, 'D')
    
    #date diff is only the difference between the two games
    #creating a column to represent the "rest" days between the games
    #"rest" in this case is the days between each game where a game is not being played and does not account for practices
    team_df["rest"] = team_df["date_diff"] - 1 
    
    
    return team_df

# %%
#test 1
bucks_df = rest_days_20('MIL')

bucks_df
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         dates results locations  game_nums opponent date_diff rest
# 0  2019-10-24     Win      Away          1      HOU        10    9
# 1  2019-10-26    Loss      Home          2      MIA         2    1
# 2  2019-10-28     Win      Home          3      CLE         2    1
# 3  2019-10-30    Loss      Away          4      BOS         2    1
# 4  2019-11-01     Win      Away          5      ORL         2    1
# ..        ...     ...       ...        ...      ...       ...  ...
# 60 2020-03-02    Loss      Away         61      MIA         1    0
# 61 2020-03-04     Win      Home         62      IND         2    1
# 62 2020-03-06    Loss      Away         63      LAL         2    1
# 63 2020-03-08    Loss      Away         64      PHO         2    1
# 64 2020-03-09    Loss      Away         65      DEN         1    0
#
# [65 rows x 7 columns]

# %%
#test 2
wolves_df = rest_days_20('MIN')

len(wolves_df)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 64

# %%
# function to add opponent date diff and rest

def advanced_rest_20(team):
    team_df = rest_days_20(team)
    
    opp_diff = []
    opp_rest = []
    
    for i in range(0,len(team_df)):
        
        
        opp_df = rest_days_20(str(team_df['opponent'][i]))
        
    
#         for opp in team_df['opponent']:
#             opp_df = rest_days_20(str(opp))
        
        opp_diff.append(opp_df['date_diff'][i])
        opp_rest.append(opp_df['rest'][i])
        
    team_df['opp_date_diff'] = opp_diff
    team_df['opp_rest'] = opp_rest
    
    team_df['rest_diff'] = team_df['rest'] - team_df['opp_rest']
    
    
    
    return team_df

# %%
#test 3

wolves_adv_df = advanced_rest_20('MIN')

wolves_adv_df.head(10)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        dates results locations  game_nums opponent date_diff rest  \
# 0 2019-10-23     Win      Away          1      BRK        10    9
# 1 2019-10-25     Win      Away          2      CHO         2    1
# 2 2019-10-27     Win      Home          3      MIA         2    1
# 3 2019-10-30    Loss      Away          4      PHI         3    2
# 4 2019-11-02     Win      Away          5      WAS         3    2
# 5 2019-11-04    Loss      Home          6      MIL         2    1
# 6 2019-11-06    Loss      Away          7      MEM         2    1
# 7 2019-11-08     Win      Home          8      GSW         2    1
# 8 2019-11-10    Loss      Home          9      DEN         2    1
# 9 2019-11-11     Win      Away         10      DET         1    0
#
#    opp_date_diff  opp_rest rest_diff
# 0           10.0       9.0         0
# 1            2.0       1.0         0
# 2            1.0       0.0         1
# 3            2.0       1.0         1
# 4            3.0       2.0         0
# 5            1.0       0.0         1
# 6            2.0       1.0         0
# 7            2.0       1.0         0
# 8            2.0       1.0         0
# 9            2.0       1.0        -1

# %%
wolves_adv_df.dtypes
# Out:
# dates            datetime64[ns]
# results                  object
# locations                object
# game_nums                 int64
# opponent                 object
# date_diff                object
# rest                     object
# opp_date_diff           float64
# opp_rest                float64
# rest_diff                object
# dtype: object

# %%
#better function

def adv_rest_20(team):
    #creating the rest day calc function

    def rest_days_20(team):

        #creating the team schedule
        schedule = Schedule(team, 2020)

        dates = []
        results = []
        locations = []
        game_nums = []
        opponents = []



        for game in schedule:

            if game.playoffs == False and game.datetime < datetime(2020,7,15):
                dates.append(game.datetime)
                results.append(game.result)
                locations.append(game.location)
                game_nums.append(game.game)
                opponents.append(game.opponent_abbr)

        #creating team dictionary
        team_dict = {
            "dates": dates,
            "results": results,
            "locations": locations,
            "game_nums": game_nums,
            "opponent": opponents
        }

        #creating bucks data frame
        team_df = pd.DataFrame(team_dict)
        team_df

        #finding the number of games between each game
        team_df["date_diff"] = 0

        for i in range(1,len(team_df)):    
            team_df["date_diff"][i] = team_df["dates"][i] - team_df["dates"][(i-1)]

        #inserting value for the date diff in the first game
        #using 10 as a standard for the date difference of the first game (most impactful players don't play preseason anyway)
        team_df["date_diff"][0] = 10

        #converting to a time delta
        team_df["date_diff"][0] = pd.to_timedelta(team_df["date_diff"][0], unit = "D")

        #Converting the date difference series back into an integer for easier comparisons
        for day in range(0,len(team_df["date_diff"])):
            team_df["date_diff"][day] = team_df["date_diff"][day] / np.timedelta64(1, 'D')

        #date diff is only the difference between the two games
        #creating a column to represent the "rest" days between the games
        #"rest" in this case is the days between each game where a game is not being played and does not account for practices
        team_df["rest"] = team_df["date_diff"] - 1 

        return team_df
    
    #passing team to the inner function
    team_df = rest_days_20(team)
    
    opp_diff = []
    opp_rest = []
    
    #iterate through the games
    for i in range(0,len(team_df)):
        
        #for each opponent create a rest dataframe
        opp_df = rest_days_20(str(team_df['opponent'][i]))
        
        #append the rest to the lists
        opp_diff.append(opp_df['date_diff'][i])
        opp_rest.append(opp_df['rest'][i])
    
    #new columns for opponents' values
    team_df['opp_date_diff'] = opp_diff
    team_df['opp_rest'] = opp_rest
    
    #creating a rest difference column
    team_df['rest_diff'] = team_df['rest'] - team_df['opp_rest']
    
    return team_df

# %%
#test 2
wolves_test2 = adv_rest_20('MIN')
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wolves_test2.head(10)
# Out:
#        dates results locations  game_nums opponent date_diff rest  \
# 0 2019-10-23     Win      Away          1      BRK        10    9
# 1 2019-10-25     Win      Away          2      CHO         2    1
# 2 2019-10-27     Win      Home          3      MIA         2    1
# 3 2019-10-30    Loss      Away          4      PHI         3    2
# 4 2019-11-02     Win      Away          5      WAS         3    2
# 5 2019-11-04    Loss      Home          6      MIL         2    1
# 6 2019-11-06    Loss      Away          7      MEM         2    1
# 7 2019-11-08     Win      Home          8      GSW         2    1
# 8 2019-11-10    Loss      Home          9      DEN         2    1
# 9 2019-11-11     Win      Away         10      DET         1    0
#
#    opp_date_diff  opp_rest rest_diff
# 0           10.0       9.0         0
# 1            2.0       1.0         0
# 2            1.0       0.0         1
# 3            2.0       1.0         1
# 4            3.0       2.0         0
# 5            1.0       0.0         1
# 6            2.0       1.0         0
# 7            2.0       1.0         0
# 8            2.0       1.0         0
# 9            2.0       1.0        -1
